# %%
# !pip install pytorch_pretrained_bert
# Out:
# Requirement already satisfied: pytorch_pretrained_bert in c:\users\aryck\anaconda3\lib\site-packages (0.6.2)
# Requirement already satisfied: torch>=0.4.1 in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (2.5.1)
# Requirement already satisfied: numpy in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (2.0.2)
# Requirement already satisfied: boto3 in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (1.35.54)
# Requirement already satisfied: requests in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (2.31.0)
# Requirement already satisfied: tqdm in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (4.65.0)
# Requirement already satisfied: regex in c:\users\aryck\anaconda3\lib\site-packages (from pytorch_pretrained_bert) (2022.7.9)
# Requirement already satisfied: filelock in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (4.12.2)
# Requirement already satisfied: networkx in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1)
# Requirement already satisfied: jinja2 in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aryck\anaconda3\lib\site-packages (from torch>=0.4.1->pytorch_pretrained_bert) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aryck\anaconda3\lib\site-packages (from sympy==1.13.1->torch>=0.4.1->pytorch_pretrained_bert) (1.3.0)
# Requirement already satisfied: botocore<1.36.0,>=1.35.54 in c:\users\aryck\anaconda3\lib\site-packages (from boto3->pytorch_pretrained_bert) (1.35.54)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\aryck\anaconda3\lib\site-packages (from boto3->pytorch_pretrained_bert) (0.10.0)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\aryck\anaconda3\lib\site-packages (from boto3->pytorch_pretrained_bert) (0.10.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryck\anaconda3\lib\site-packages (from requests->pytorch_pretrained_bert) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryck\anaconda3\lib\site-packages (from requests->pytorch_pretrained_bert) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryck\anaconda3\lib\site-packages (from requests->pytorch_pretrained_bert) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryck\anaconda3\lib\site-packages (from requests->pytorch_pretrained_bert) (2023.7.22)
# Requirement already satisfied: colorama in c:\users\aryck\anaconda3\lib\site-packages (from tqdm->pytorch_pretrained_bert) (0.4.6)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in c:\users\aryck\anaconda3\lib\site-packages (from botocore<1.36.0,>=1.35.54->boto3->pytorch_pretrained_bert) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryck\anaconda3\lib\site-packages (from jinja2->torch>=0.4.1->pytorch_pretrained_bert) (2.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\aryck\anaconda3\lib\site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.36.0,>=1.35.54->boto3->pytorch_pretrained_bert) (1.16.0)

# %%
# !pip install fastai
# Out:
# Requirement already satisfied: fastai in c:\users\aryck\anaconda3\lib\site-packages (2.7.18)
# Requirement already satisfied: pip in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (24.3.1)
# Requirement already satisfied: packaging in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (23.1)
# Requirement already satisfied: fastdownload<2,>=0.0.5 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (0.0.7)
# Requirement already satisfied: fastcore<1.8,>=1.5.29 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (1.7.19)
# Requirement already satisfied: torchvision>=0.11 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (0.20.1)
# Requirement already satisfied: matplotlib in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (3.7.2)
# Requirement already satisfied: pandas in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (1.5.3)
# Requirement already satisfied: requests in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (2.31.0)
# Requirement already satisfied: pyyaml in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (6.0)
# Requirement already satisfied: fastprogress>=0.2.4 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (1.0.3)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (9.4.0)
# Requirement already satisfied: scikit-learn in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (1.3.0)
# Requirement already satisfied: scipy in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (1.14.1)
# Requirement already satisfied: spacy<4 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (3.8.2)
# Requirement already satisfied: torch<2.6,>=1.10 in c:\users\aryck\anaconda3\lib\site-packages (from fastai) (2.5.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (0.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (4.65.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (3.4.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy<4->fastai) (2.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryck\anaconda3\lib\site-packages (from requests->fastai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryck\anaconda3\lib\site-packages (from requests->fastai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryck\anaconda3\lib\site-packages (from requests->fastai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryck\anaconda3\lib\site-packages (from requests->fastai) (2023.7.22)
# Requirement already satisfied: filelock in c:\users\aryck\anaconda3\lib\site-packages (from torch<2.6,>=1.10->fastai) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\aryck\anaconda3\lib\site-packages (from torch<2.6,>=1.10->fastai) (4.12.2)
# Requirement already satisfied: networkx in c:\users\aryck\anaconda3\lib\site-packages (from torch<2.6,>=1.10->fastai) (3.1)
# Requirement already satisfied: fsspec in c:\users\aryck\anaconda3\lib\site-packages (from torch<2.6,>=1.10->fastai) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\aryck\anaconda3\lib\site-packages (from torch<2.6,>=1.10->fastai) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\aryck\anaconda3\lib\site-packages (from sympy==1.13.1->torch<2.6,>=1.10->fastai) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (1.4.4)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib->fastai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryck\anaconda3\lib\site-packages (from pandas->fastai) (2023.3.post1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\aryck\anaconda3\lib\site-packages (from scikit-learn->fastai) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from scikit-learn->fastai) (2.2.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\aryck\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.0)
# Requirement already satisfied: six>=1.5 in c:\users\aryck\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->fastai) (1.16.0)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy<4->fastai) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy<4->fastai) (0.1.5)
# Requirement already satisfied: colorama in c:\users\aryck\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<4->fastai) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (8.0.4)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aryck\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy<4->fastai) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\aryck\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\aryck\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy<4->fastai) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryck\anaconda3\lib\site-packages (from jinja2->spacy<4->fastai) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\aryck\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<4->fastai) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aryck\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aryck\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy<4->fastai) (0.1.0)

# %%
from transformers import pipeline
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\aryck\AppData\Local\Temp\ipykernel_44144\4287807559.py", line 1, in <module>
#     from transformers import pipeline
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\transformers\utils\import_utils.py", line 1120, in __getattr__
#     module = self._get_module(self._class_to_module[name])
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\transformers\utils\import_utils.py", line 1130, in _get_module
#     return importlib.import_module("." + module_name, self.__name__)
#   File "C:\Users\aryck\anaconda3\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py", line 28, in <module>
#     from ..image_processing_utils import BaseImageProcessor
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\transformers\image_processing_utils.py", line 28, in <module>
#     from .image_transforms import center_crop, normalize, rescale
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\transformers\image_transforms.py", line 47, in <module>
#     import tensorflow as tf
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\__init__.py", line 47, in <module>
#     from tensorflow._api.v2 import __internal__
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py", line 11, in <module>
#     from tensorflow._api.v2.__internal__ import distribute
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py", line 8, in <module>
#     from tensorflow._api.v2.__internal__.distribute import combinations
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py", line 8, in <module>
#     from tensorflow.python.distribute.combinations import env # line: 456
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\combinations.py", line 33, in <module>
#     from tensorflow.python.distribute import collective_all_reduce_strategy
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py", line 25, in <module>
#     from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\cross_device_ops.py", line 28, in <module>
#     from tensorflow.python.distribute import cross_device_utils
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\cross_device_utils.py", line 22, in <module>
#     from tensorflow.python.distribute import values as value_lib
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\values.py", line 23, in <module>
#     from tensorflow.python.distribute import distribute_lib
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py", line 205, in <module>
#     from tensorflow.python.data.ops import dataset_ops
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py", line 34, in <module>
#     from tensorflow.python.data.ops import iterator_ops
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py", line 45, in <module>
#     from tensorflow.python.training.saver import BaseSaverBuilder
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\training\saver.py", line 50, in <module>
#     from tensorflow.python.training import py_checkpoint_reader
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py", line 19, in <module>
#     from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1130, in _LazyModule._get_module(self, module_name)
#    1129 try:
# -> 1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
#
# File ~\anaconda3\Lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1204, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1176, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1147, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:690, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:940, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:241, in _call_with_frames_removed(f, *args, **kwds)
#
# File ~\anaconda3\Lib\site-packages\transformers\pipelines\__init__.py:28
#      27 from ..feature_extraction_utils import PreTrainedFeatureExtractor
# ---> 28 from ..image_processing_utils import BaseImageProcessor
#      29 from ..models.auto.configuration_auto import AutoConfig
#
# File ~\anaconda3\Lib\site-packages\transformers\image_processing_utils.py:28
#      27 from .feature_extraction_utils import BatchFeature as BaseBatchFeature
# ---> 28 from .image_transforms import center_crop, normalize, rescale
#      29 from .image_utils import ChannelDimension
#
# File ~\anaconda3\Lib\site-packages\transformers\image_transforms.py:47
#      46 if is_tf_available():
# ---> 47     import tensorflow as tf
#      49 if is_flax_available():
#
# File ~\anaconda3\Lib\site-packages\tensorflow\__init__.py:47
#      45 _tf2.enable()
# ---> 47 from tensorflow._api.v2 import __internal__
#      48 from tensorflow._api.v2 import __operators__
#
# File ~\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#      10 from tensorflow._api.v2.__internal__ import dispatch
# ---> 11 from tensorflow._api.v2.__internal__ import distribute
#      12 from tensorflow._api.v2.__internal__ import eager_context
#
# File ~\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow._api.v2.__internal__.distribute import combinations
#       9 from tensorflow._api.v2.__internal__.distribute import interim
#
# File ~\anaconda3\Lib\site-packages\tensorflow\_api\v2\__internal__\distribute\combinations\__init__.py:8
#       6 import sys as _sys
# ----> 8 from tensorflow.python.distribute.combinations import env # line: 456
#       9 from tensorflow.python.distribute.combinations import generate # line: 365
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\combinations.py:33
#      32 from tensorflow.python.client import session
# ---> 33 from tensorflow.python.distribute import collective_all_reduce_strategy
#      34 from tensorflow.python.distribute import distribute_lib
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\collective_all_reduce_strategy.py:25
#      24 from tensorflow.python.distribute import collective_util
# ---> 25 from tensorflow.python.distribute import cross_device_ops as cross_device_ops_lib
#      26 from tensorflow.python.distribute import cross_device_utils
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\cross_device_ops.py:28
#      27 from tensorflow.python.distribute import collective_util
# ---> 28 from tensorflow.python.distribute import cross_device_utils
#      29 from tensorflow.python.distribute import device_util
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\cross_device_utils.py:22
#      21 from tensorflow.python.distribute import collective_util
# ---> 22 from tensorflow.python.distribute import values as value_lib
#      23 from tensorflow.python.eager import backprop_util
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\values.py:23
#      22 from tensorflow.python.distribute import device_util
# ---> 23 from tensorflow.python.distribute import distribute_lib
#      24 from tensorflow.python.distribute import packed_distributed_variable as packed
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\distribute\distribute_lib.py:205
#     204 from tensorflow.python.autograph.impl import api as autograph
# --> 205 from tensorflow.python.data.ops import dataset_ops
#     206 from tensorflow.python.distribute import collective_util
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\dataset_ops.py:34
#      33 from tensorflow.python.data.ops import debug_mode
# ---> 34 from tensorflow.python.data.ops import iterator_ops
#      35 from tensorflow.python.data.ops import options as options_lib
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\data\ops\iterator_ops.py:45
#      44 from tensorflow.python.trackable import base as trackable
# ---> 45 from tensorflow.python.training.saver import BaseSaverBuilder
#      46 from tensorflow.python.util import deprecation
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\training\saver.py:50
#      49 from tensorflow.python.trackable import base as trackable
# ---> 50 from tensorflow.python.training import py_checkpoint_reader
#      51 from tensorflow.python.training import training_util
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\training\py_checkpoint_reader.py:19
#      18 from tensorflow.python.util import compat
# ---> 19 from tensorflow.python.util._pywrap_checkpoint_reader import CheckpointReader
#      20 from tensorflow.python.util.tf_export import tf_export
#
# SystemError: initialization of _pywrap_checkpoint_reader raised unreported exception
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from transformers import pipeline
#
# File <frozen importlib._bootstrap>:1229, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1120, in _LazyModule.__getattr__(self, name)
#    1118     value = self._get_module(name)
#    1119 elif name in self._class_to_module.keys():
# -> 1120     module = self._get_module(self._class_to_module[name])
#    1121     value = getattr(module, name)
#    1122 else:
#
# File ~\anaconda3\Lib\site-packages\transformers\utils\import_utils.py:1132, in _LazyModule._get_module(self, module_name)
#    1130     return importlib.import_module("." + module_name, self.__name__)
#    1131 except Exception as e:
# -> 1132     raise RuntimeError(
#    1133         f"Failed to import {self.__name__}.{module_name} because of the following error (look up to see its"
#    1134         f" traceback):\n{e}"
#    1135     ) from e
#
# RuntimeError: Failed to import transformers.pipelines because of the following error (look up to see its traceback):
# initialization of _pywrap_checkpoint_reader raised unreported exception

# %%
from transformers import BertTokenizer, BertModel
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertModel.from_pretrained("bert-base-uncased")
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='pt')
output = model(**encoded_input)
# Out:
# C:\Users\aryck\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# C:\Users\aryck\anaconda3\Lib\site-packages\transformers\utils\generic.py:260: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   torch.utils._pytree._register_pytree_node(
# C:\Users\aryck\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:1142: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# !pip install numpy<2
# Out:
# O sistema não pode encontrar o arquivo especificado.

# %%
from pytorch_pretrained_bert.tokenization import BertTokenizer, WordpieceTokenizer
from pytorch_pretrained_bert.modeling import BertForPreTraining, BertPreTrainedModel, BertModel, BertConfig, BertForMaskedLM, BertForSequenceClassification
from pathlib import Path
import torch
import re
from torch import Tensor
from torch.nn import BCEWithLogitsLoss
from fastai.text.all import WordTokenizer
tokenizer = WordTokenizer()
from fastai.text import Vocab
import pandas as pd
import collections
import os
import pdb
from tqdm import tqdm, trange
import sys
import random
import numpy as np
import apex
from sklearn.model_selection import train_test_split
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from sklearn.metrics import roc_curve, auc

from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
from torch.utils.data.distributed import DistributedSampler
from pytorch_pretrained_bert.optimization import BertAdam
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\aryck\AppData\Local\Temp\ipykernel_45992\1172506597.py", line 8, in <module>
#     from fastai.text.all import WordTokenizer
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\fastai\text\all.py", line 1, in <module>
#     from ..basics import *
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\fastai\basics.py", line 1, in <module>
#     from .data.all import *
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\fastai\data\all.py", line 1, in <module>
#     from ..torch_basics import *
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\fastai\torch_basics.py", line 9, in <module>
#     from .imports import *
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\fastai\imports.py", line 5, in <module>
#     import multiprocessing,threading,urllib,tempfile,concurrent.futures,matplotlib,warnings,zipfile
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\__init__.py", line 129, in <module>
#     from . import _api, _version, cbook, _docstring, rcsetup
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\rcsetup.py", line 27, in <module>
#     from matplotlib.colors import Colormap, is_color_like
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\colors.py", line 56, in <module>
#     from matplotlib import _api, _cm, cbook, scale
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\scale.py", line 22, in <module>
#     from matplotlib.ticker import (
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\ticker.py", line 138, in <module>
#     from matplotlib import transforms as mtransforms
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\matplotlib\transforms.py", line 49, in <module>
#     from matplotlib._path import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 8
#       6 from torch import Tensor
#       7 from torch.nn import BCEWithLogitsLoss
# ----> 8 from fastai.text.all import WordTokenizer
#       9 tokenizer = WordTokenizer()
#      10 from fastai.text import Vocab
#
# File ~\anaconda3\Lib\site-packages\fastai\text\all.py:1
# ----> 1 from ..basics import *
#       2 from ..callback.all import *
#       3 from .core import *
#
# File ~\anaconda3\Lib\site-packages\fastai\basics.py:1
# ----> 1 from .data.all import *
#       2 from .optimizer import *
#       3 from .callback.core import *
#
# File ~\anaconda3\Lib\site-packages\fastai\data\all.py:1
# ----> 1 from ..torch_basics import *
#       2 from .core import *
#       3 from .load import *
#
# File ~\anaconda3\Lib\site-packages\fastai\torch_basics.py:9
#       6     # workaround "OMP: Error #15: Initializing libiomp5.dylib, but found libomp.dylib already initialized"
#       7     os.environ['KMP_DUPLICATE_LIB_OK'] = 'True'
# ----> 9 from .imports import *
#      10 from .torch_imports import *
#      11 from .torch_core import *
#
# File ~\anaconda3\Lib\site-packages\fastai\imports.py:5
#       3 import io,operator,sys,os,re,mimetypes,csv,itertools,json,shutil,glob,pickle,tarfile,collections
#       4 import hashlib,itertools,types,inspect,functools,random,time,math,bz2,typing,numbers,string
# ----> 5 import multiprocessing,threading,urllib,tempfile,concurrent.futures,matplotlib,warnings,zipfile
#       7 from concurrent.futures import as_completed
#       8 from functools import partial,reduce
#
# File ~\anaconda3\Lib\site-packages\matplotlib\__init__.py:129
#     125 from packaging.version import parse as parse_version
#     127 # cbook must import matplotlib only within function
#     128 # definitions, so it is safe to import from it here.
# --> 129 from . import _api, _version, cbook, _docstring, rcsetup
#     130 from matplotlib.cbook import sanitize_sequence
#     131 from matplotlib._api import MatplotlibDeprecationWarning
#
# File ~\anaconda3\Lib\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:56
#      54 import matplotlib as mpl
#      55 import numpy as np
# ---> 56 from matplotlib import _api, _cm, cbook, scale
#      57 from ._color_data import BASE_COLORS, TABLEAU_COLORS, CSS4_COLORS, XKCD_COLORS
#      60 class _ColorMapping(dict):
#
# File ~\anaconda3\Lib\site-packages\matplotlib\scale.py:22
#      20 import matplotlib as mpl
#      21 from matplotlib import _api, _docstring
# ---> 22 from matplotlib.ticker import (
#      23     NullFormatter, ScalarFormatter, LogFormatterSciNotation, LogitFormatter,
#      24     NullLocator, LogLocator, AutoLocator, AutoMinorLocator,
#      25     SymmetricalLogLocator, AsinhLocator, LogitLocator)
#      26 from matplotlib.transforms import Transform, IdentityTransform
#      29 class ScaleBase:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\ticker.py:138
#     136 import matplotlib as mpl
#     137 from matplotlib import _api, cbook
# --> 138 from matplotlib import transforms as mtransforms
#     140 _log = logging.getLogger(__name__)
#     142 __all__ = ('TickHelper', 'Formatter', 'FixedFormatter',
#     143            'NullFormatter', 'FuncFormatter', 'FormatStrFormatter',
#     144            'StrMethodFormatter', 'ScalarFormatter', 'LogFormatter',
#    (...)
#     150            'MultipleLocator', 'MaxNLocator', 'AutoMinorLocator',
#     151            'SymmetricalLogLocator', 'AsinhLocator', 'LogitLocator')
#
# File ~\anaconda3\Lib\site-packages\matplotlib\transforms.py:49
#      46 from numpy.linalg import inv
#      48 from matplotlib import _api
# ---> 49 from matplotlib._path import (
#      50     affine_transform, count_bboxes_overlapping_bbox, update_path_extents)
#      51 from .path import Path
#      53 DEBUG = False
#
# ImportError: numpy.core.multiarray failed to import

# %% [markdown]
# ## Data Representation class

# %%
class ImputExample(object):
    
    # construtores
    def __init__(self, guid, text_a, text_b=None, labels=None):
        
        self.guid = guid # atribuir um ID unico para o exemplo
        self.text_a = text_a # primeira sequencia (não tokenizada)
        self.text_b = text_b # opcional: somente para tarefas de pares de sequências
        self.labels = labels # a classificação da sequencia (apenas para os exemplos de treino)

# %%
class InputFeatures(object):
    
    # caracteristicas dos dados
    def __init__(self, input_ids, input_mask, segment_ids, label_ids):
        self.input_ids = input_ids
        self.input_mask = input_mask
        self.segment_ids = segment_ids
        self.label_ids = label_ids

# %%
class BertForMultiLabelSequenceClassification(PreTrainedBertModel):
    """BERT model for classification.
    This module is composed of the BERT model with a linear layer on top of
    the pooled output.
    """
    def __init__(self, config, num_labels=2):
        super(BertForMultiLabelSequenceClassification, self).__init__(config)
        self.num_labels = num_labels
        self.bert = BertModel(config)
        self.dropout = torch.nn.Dropout(config.hidden_dropout_prob)
        self.classifier = torch.nn.Linear(config.hidden_size, num_labels)
        self.apply(self.init_bert_weights)

    def forward(self, input_ids, token_type_ids=None, attention_mask=None, labels=None):
        _, pooled_output = self.bert(input_ids, token_type_ids, attention_mask, output_all_encoded_layers=False)
        pooled_output = self.dropout(pooled_output)
        logits = self.classifier(pooled_output)

        if labels is not None:
            loss_fct = BCEWithLogitsLoss()
            loss = loss_fct(logits.view(-1, self.num_labels), labels.view(-1, self.num_labels))
            return loss
        else:
            return logits
        
    def freeze_bert_encoder(self):
        for param in self.bert.parameters():
            param.requires_grad = False
    
    def unfreeze_bert_encoder(self):
        for param in self.bert.parameters():
            param.requires_grad = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 class BertForMultiLabelSequenceClassification(PreTrainedBertModel):
#       2     """BERT model for classification.
#       3     This module is composed of the BERT model with a linear layer on top of
#       4     the pooled output.
#       5     """
#       6     def __init__(self, config, num_labels=2):
#
# NameError: name 'PreTrainedBertModel' is not defined

# %%
BertForMultiLabelSequenceClassification(
  (bert): BertModel(
    (embeddings): BertEmbeddings(
      (word_embeddings): Embedding(28996, 768)
      (position_embeddings): Embedding(512, 768)
      (token_type_embeddings): Embedding(2, 768)
      (LayerNorm): FusedLayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
      (dropout): Dropout(p=0.1)
    )
    (encoder): BertEncoder(
      (layer): ModuleList(
#      12 BertLayers
        (11): BertLayer(
          (attention): BertAttention(
            (self): BertSelfAttention(
              (query): Linear(in_features=768, out_features=768, bias=True)
              (key): Linear(in_features=768, out_features=768, bias=True)
              (value): Linear(in_features=768, out_features=768, bias=True)
              (dropout): Dropout(p=0.1)
            )
            (output): BertSelfOutput(
              (dense): Linear(in_features=768, out_features=768, bias=True)
              (LayerNorm): FusedLayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
              (dropout): Dropout(p=0.1)
            )
          )
          (intermediate): BertIntermediate(
            (dense): Linear(in_features=768, out_features=3072, bias=True)
          )
          (output): BertOutput(
            (dense): Linear(in_features=3072, out_features=768, bias=True)
            (LayerNorm): FusedLayerNorm(torch.Size([768]), eps=1e-12, elementwise_affine=True)
            (dropout): Dropout(p=0.1)
          )
        )
      )
    )
    (pooler): BertPooler(
      (dense): Linear(in_features=768, out_features=768, bias=True)
      (activation): Tanh()
    )
  )
  (dropout): Dropout(p=0.1)
  (classifier): Linear(in_features=768, out_features=6, bias=True)
)
