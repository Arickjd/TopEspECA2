# %%
# !pip install convokit
# Out:
# Collecting convokit
#   Downloading convokit-3.0.0.tar.gz (183 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (3.7.2)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (1.5.3)
# Collecting msgpack-numpy>=0.4.3.2 (from convokit)
#   Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: spacy>=2.3.5 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (3.8.2)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (1.14.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (1.3.0)
# Requirement already satisfied: nltk>=3.4 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (3.8.1)
# Requirement already satisfied: dill>=0.2.9 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (0.3.6)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (1.2.0)
# Collecting clean-text>=0.6.0 (from convokit)
#   Downloading clean_text-0.6.0-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: unidecode>=1.1.1 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (1.2.0)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (4.65.0)
# Collecting pymongo>=4.0 (from convokit)
#   Downloading pymongo-4.10.1-cp311-cp311-win_amd64.whl.metadata (22 kB)
# Requirement already satisfied: pyyaml>=5.4.1 in c:\users\aryck\anaconda3\lib\site-packages (from convokit) (6.0)
# Collecting dnspython>=1.16.0 (from convokit)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting emoji<2.0.0,>=1.0.0 (from clean-text>=0.6.0->convokit)
#   Downloading emoji-1.7.0.tar.gz (175 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ftfy<7.0,>=6.0 in c:\users\aryck\anaconda3\lib\site-packages (from clean-text>=0.6.0->convokit) (6.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (1.4.4)
# Requirement already satisfied: numpy>=1.20 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aryck\anaconda3\lib\site-packages (from matplotlib>=3.0.0->convokit) (2.8.2)
# Requirement already satisfied: msgpack>=0.5.2 in c:\users\aryck\anaconda3\lib\site-packages (from msgpack-numpy>=0.4.3.2->convokit) (1.0.3)
# Requirement already satisfied: click in c:\users\aryck\anaconda3\lib\site-packages (from nltk>=3.4->convokit) (8.0.4)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\aryck\anaconda3\lib\site-packages (from nltk>=3.4->convokit) (2022.7.9)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryck\anaconda3\lib\site-packages (from pandas>=0.23.4->convokit) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->convokit) (2.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (8.3.2)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (0.12.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (1.10.8)
# Requirement already satisfied: jinja2 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (3.1.2)
# Requirement already satisfied: setuptools in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (68.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from spacy>=2.3.5->convokit) (3.4.1)
# Requirement already satisfied: colorama in c:\users\aryck\anaconda3\lib\site-packages (from tqdm>=4.64.0->convokit) (0.4.6)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in c:\users\aryck\anaconda3\lib\site-packages (from ftfy<7.0,>=6.0->clean-text>=0.6.0->convokit) (0.2.13)
# Requirement already satisfied: language-data>=1.2 in c:\users\aryck\anaconda3\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=2.3.5->convokit) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=2.3.5->convokit) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\aryck\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->convokit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryck\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryck\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryck\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryck\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=2.3.5->convokit) (2023.7.22)
# Requirement already satisfied: blis<1.1.0,>=1.0.0 in c:\users\aryck\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=2.3.5->convokit) (1.0.1)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\aryck\anaconda3\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=2.3.5->convokit) (0.1.5)
# Collecting numpy>=1.20 (from matplotlib>=3.0.0->convokit)
#   Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl.metadata (59 kB)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\aryck\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.3.5->convokit) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\aryck\anaconda3\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=2.3.5->convokit) (13.8.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\aryck\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.3.5->convokit) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\aryck\anaconda3\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=2.3.5->convokit) (5.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryck\anaconda3\lib\site-packages (from jinja2->spacy>=2.3.5->convokit) (2.1.1)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\aryck\anaconda3\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=2.3.5->convokit) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aryck\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.3.5->convokit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aryck\anaconda3\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.3.5->convokit) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aryck\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=2.3.5->convokit) (0.1.0)
# Downloading clean_text-0.6.0-py3-none-any.whl (11 kB)
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
# Downloading msgpack_numpy-0.4.8-py2.py3-none-any.whl (6.9 kB)
# Downloading pymongo-4.10.1-cp311-cp311-win_amd64.whl (876 kB)
#    ---------------------------------------- 0.0/876.5 kB ? eta -:--:--
#    ----------------------- ---------------- 524.3/876.5 kB 2.4 MB/s eta 0:00:01
#    ---------------------------------------- 876.5/876.5 kB 2.8 MB/s eta 0:00:00
# Using cached numpy-2.0.2-cp311-cp311-win_amd64.whl (15.9 MB)
# Building wheels for collected packages: convokit, emoji
#   Building wheel for convokit (pyproject.toml): started
#   Building wheel for convokit (pyproject.toml): finished with status 'done'
#   Created wheel for convokit: filename=convokit-3.0.0-py3-none-any.whl size=216715 sha256=755a7656888f3f1937af917c0c4b885d407035bec4b98a540c79b83321a8b6d1
#   Stored in directory: c:\users\aryck\appdata\local\pip\cache\wheels\b8\31\db\a09c7f65734811ce7dbed30f49888d7c2952f0729a12da9020
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171059 sha256=0159cdb5b528433986568e821bca641d2c97b5cb8a8e25795d01d290c917a6bd
#   Stored in directory: c:\users\aryck\appdata\local\pip\cache\wheels\bd\22\e5\b69726d5e1a19795ecd3b3e7464b16c0f1d019aa94ff1c8578
# Successfully built convokit emoji
# Installing collected packages: emoji, numpy, dnspython, pymongo, msgpack-numpy, clean-text, convokit
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.0
#     Uninstalling numpy-1.25.0:
#       Successfully uninstalled numpy-1.25.0
# Successfully installed clean-text-0.6.0 convokit-3.0.0 dnspython-2.7.0 emoji-1.7.0 msgpack-numpy-0.4.8 numpy-2.0.2 pymongo-4.10.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\aryck\anaconda3\Lib\site-packages\~~mpy'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# numba 0.57.1 requires numpy<1.25,>=1.21, but you have numpy 2.0.2 which is incompatible.
# pyfume 0.3.4 requires numpy==1.24.4, but you have numpy 2.0.2 which is incompatible.
# pyfume 0.3.4 requires scipy==1.10.1, but you have scipy 1.14.1 which is incompatible.
# tensorflow-intel 2.17.0 requires numpy<2.0.0,>=1.23.5; python_version <= "3.11", but you have numpy 2.0.2 which is incompatible.

# %%
import os
from pathlib import Path
import torch
import re
import random
import transformers, datasets
from tokenizers import BertWordPieceTokenizer
from transformers import BertTokenizer
import tqdm
from torch.utils.data import Dataset, DataLoader
import itertools
import math
import torch.nn.functional as F
import numpy as np
from torch.optim import Adam
MAX_LEN = 64
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\traitlets\config\application.py", line 992, in launch_instance
#     app.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\tornado\platform\asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 607, in run_forever
#     self._run_once()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\base_events.py", line 1922, in _run_once
#     handle._run()
#   File "C:\Users\aryck\anaconda3\Lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\ipykernel\zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3024, in run_cell
#     result = self._run_cell(
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3079, in _run_cell
#     result = runner(coro)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3284, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3466, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py", line 3526, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\aryck\AppData\Local\Temp\ipykernel_30256\3494106646.py", line 6, in <module>
#     import transformers, datasets
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\datasets\__init__.py", line 24, in <module>
#     import pyarrow
#   File "C:\Users\aryck\anaconda3\Lib\site-packages\pyarrow\__init__.py", line 65, in <module>
#     import pyarrow.lib as _lib
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 6
#       4 import re
#       5 import random
# ----> 6 import transformers, datasets
#       7 from tokenizers import BertWordPieceTokenizer
#       8 from transformers import BertTokenizer
#
# File ~\anaconda3\Lib\site-packages\datasets\__init__.py:24
#      20 __version__ = "2.12.0"
#      22 import platform
# ---> 24 import pyarrow
#      25 from packaging import version
#      28 if version.parse(platform.python_version()) < version.parse("3.7"):
#
# File ~\anaconda3\Lib\site-packages\pyarrow\__init__.py:65
#      63 _gc_enabled = _gc.isenabled()
#      64 _gc.disable()
# ---> 65 import pyarrow.lib as _lib
#      66 if _gc_enabled:
#      67     _gc.enable()
#
# File ~\anaconda3\Lib\site-packages\pyarrow\lib.pyx:37, in init pyarrow.lib()
#
# ImportError: numpy.core.multiarray failed to import

# %%
from convokit import Corpus, download
corpus = Corpus(filename=download("movie-corpus"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from convokit import Corpus, download
#       2 corpus = Corpus(filename=download("movie-corpus"))
#
# File ~\anaconda3\Lib\site-packages\convokit\__init__.py:1
# ----> 1 from .model import *
#       2 from .util import *
#       3 from .coordination import *
#
# File ~\anaconda3\Lib\site-packages\convokit\model\__init__.py:1
# ----> 1 from .conversation import Conversation
#       2 from .convoKitIndex import ConvoKitIndex
#       3 from .convoKitMatrix import ConvoKitMatrix
#
# File ~\anaconda3\Lib\site-packages\convokit\model\conversation.py:6
#       4 from convokit.util import warn
#       5 from .corpusComponent import CorpusComponent
# ----> 6 from .corpusUtil import *
#       7 from .speaker import Speaker
#       8 from .utterance import Utterance
#
# File ~\anaconda3\Lib\site-packages\convokit\model\corpusUtil.py:6
#       1 """
#       2 Contains various methods used by Corpus components
#       3
#       4 """
# ----> 6 import pandas as pd
#       9 def get_utterances_dataframe(obj, selector=lambda utt: True, exclude_meta: bool = False):
#      10     """
#      11     Get a DataFrame of the utterances of a given object with fields and metadata attributes,
#      12     with an optional selector that filters for utterances that should be included.
#    (...)
#      18     :return: a pandas DataFrame
#      19     """
#
# File ~\anaconda3\Lib\site-packages\pandas\__init__.py:22
#      19 del _hard_dependencies, _dependency, _missing_dependencies
#      21 # numpy compat
# ---> 22 from pandas.compat import is_numpy_dev as _is_numpy_dev  # pyright: ignore # noqa:F401
#      24 try:
#      25     from pandas._libs import hashtable as _hashtable, lib as _lib, tslib as _tslib
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\__init__.py:18
#      15 from typing import TYPE_CHECKING
#      17 from pandas._typing import F
# ---> 18 from pandas.compat.numpy import (
#      19     is_numpy_dev,
#      20     np_version_under1p21,
#      21 )
#      22 from pandas.compat.pyarrow import (
#      23     pa_version_under1p01,
#      24     pa_version_under2p0,
#    (...)
#      31     pa_version_under9p0,
#      32 )
#      34 if TYPE_CHECKING:
#
# File ~\anaconda3\Lib\site-packages\pandas\compat\numpy\__init__.py:4
#       1 """ support numpy compatibility across versions """
#       2 import numpy as np
# ----> 4 from pandas.util.version import Version
#       6 # numpy versioning
#       7 _np_version = np.__version__
#
# File ~\anaconda3\Lib\site-packages\pandas\util\__init__.py:2
#       1 # pyright: reportUnusedImport = false
# ----> 2 from pandas.util._decorators import (  # noqa:F401
#       3     Appender,
#       4     Substitution,
#       5     cache_readonly,
#       6 )
#       8 from pandas.core.util.hashing import (  # noqa:F401
#       9     hash_array,
#      10     hash_pandas_object,
#      11 )
#      14 def __getattr__(name):
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:14
#       6 from typing import (
#       7     Any,
#       8     Callable,
#       9     Mapping,
#      10     cast,
#      11 )
#      12 import warnings
# ---> 14 from pandas._libs.properties import cache_readonly
#      15 from pandas._typing import (
#      16     F,
#      17     T,
#      18 )
#      19 from pandas.util._exceptions import find_stack_level
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\__init__.py:13
#       1 __all__ = [
#       2     "NaT",
#       3     "NaTType",
#    (...)
#       9     "Interval",
#      10 ]
# ---> 13 from pandas._libs.interval import Interval
#      14 from pandas._libs.tslibs import (
#      15     NaT,
#      16     NaTType,
#    (...)
#      21     iNaT,
#      22 )
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\interval.pyx:1, in init pandas._libs.interval()
#
# ValueError: numpy.dtype size changed, may indicate binary incompatibility. Expected 96 from C header, got 88 from PyObject
